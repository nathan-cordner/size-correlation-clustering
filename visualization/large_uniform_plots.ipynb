# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Amazon, K = 50

# %%
# New methods
pivot_scores = [899795,894073,914995,898161,901354,897429,895642,909009,899034,912353]
pivot_ls_scores = [623417,623683,623522,623481,623754,623529,623483,623712,623650,623567]
vote_scores = [686015,685941,685519,686015,685635,685637,685807,686279,685526,686069]
vote_ls_scores = [624539,624386,624339,624471,624239,624294,624617,624438,624134,624327]

scores_list = [pivot_scores, pivot_ls_scores, vote_scores, vote_ls_scores]

mean_scores = [np.mean(x) for x in scores_list]
print(mean_scores)
std_scores = [np.std(x) for x in scores_list]

plot_names = ["Pivot", "PLS", "Vote", "VLS"]
x_pos = np.arange(len(plot_names))

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_scores, yerr=std_scores, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Objective Value')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Amazon Objective Values, K = 50')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
# plt.savefig('bar_plot_with_error_bars.png')
plt.ylim(550000)
plt.show()
# Out:
# [902184.5, 623579.8, 685844.3, 624378.4]

# %% [markdown]
# ### Amazon, K = 100

# %%
# New methods
pivot_scores = [908293,916360,910858,907511,909607,903347,906422,913890,905241,919140]
pivot_ls_scores = [623522,623681,623382,623526,623768,623878,623408,623843,623498,623554]
vote_scores = [685438,685894,685363,685723,685624,686326,685294,686066,685414,685505]
vote_ls_scores = [624217,624143,624211,624409,624154,624277,624193,624323,623989,624194]

scores_list = [pivot_scores, pivot_ls_scores, vote_scores, vote_ls_scores]

mean_scores = [np.mean(x) for x in scores_list]
print(mean_scores)
std_scores = [np.std(x) for x in scores_list]

plot_names = ["Pivot", "PLS", "Vote", "VLS"]
x_pos = np.arange(len(plot_names))

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_scores, yerr=std_scores, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Objective Value')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Amazon Objective Values, K = 100')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
# plt.savefig('bar_plot_with_error_bars.png')
plt.ylim(550000)
plt.show()
# Out:
# [910066.9, 623606.0, 685664.7, 624211.0]

# %% [markdown]
# ### Amazon Times

# %%
pm5_times = [219.0,124.0,108.0,121.0,94.0,105.0,98.0,95.0,93.0,96.0]
imp5_times = [799.0,877.0,520.0,479.0,451.0,537.0,474.0,518.0,461.0,519.0]

pm10_times = [97.0,94.0,102.0,128.0,94.0,122.0,95.0,98.0,99.0,102.0]
imp10_times = [515.0,449.0,520.0,714.0,477.0,654.0,530.0,515.0,479.0,552.0]

times_list = [pm5_times, imp5_times, pm10_times, imp10_times]
times_list = [[i / 1000 for i in x] for x in times_list]

mean_times = [np.mean(x) for x in times_list]
print(mean_times)

std_times = [np.std(x) for x in times_list]

plot_names = ["Pivot 50", "Vote 50", "Pivot 100", "Vote 100"]
x_pos = np.arange(len(plot_names))

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_times, yerr=std_times, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Time (s)')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Amazon Times')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
# plt.savefig('bar_plot_with_error_bars.png')
plt.show()
# Out:
# [0.1153, 0.5635000000000001, 0.10310000000000001, 0.5405000000000001]

# %% [markdown]
# ### DBLP, K = 50

# %%
# New methods
pivot_scores = [941640,942217,946241,930723,932701,930552,939335,936734,939768,950496]
pivot_ls_scores = [620494,620277,620256,620115,620402,620165,620683,620464,620214,620231]
vote_scores = [683670,684229,683857,684500,683004,684291,684087,683991,682790,683869]
vote_ls_scores = [620910,621042,621206,621183,620804,621281,621242,621158,620775,621066]

scores_list = [pivot_scores, pivot_ls_scores, vote_scores, vote_ls_scores]

mean_scores = [np.mean(x) for x in scores_list]
print(mean_scores)
std_scores = [np.std(x) for x in scores_list]

plot_names = ["Pivot", "PLS", "Vote", "VLS"]
x_pos = np.arange(len(plot_names))

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_scores, yerr=std_scores, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Objective Value')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('DBLP Objective Values, K = 50')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
# plt.savefig('bar_plot_with_error_bars.png')
plt.ylim(550000)
plt.show()
# Out:
# [939040.7, 620330.1, 683828.8, 621066.7]

# %% [markdown]
# ### DBLP, K = 100

# %%
# New methods
pivot_scores = [966699,976391,936743,952185,976592,970588,954311,966117,963195,955871]
pivot_ls_scores = [614633,614171,614882,614871,614455,614641,614668,614664,614488,614534]
vote_scores = [677337,678151,678283,677893,678798,678451,677677,679422,678430,679310]
vote_ls_scores = [615145,615479,615800,615294,615687,615366,615675,615399,615261,615655]

scores_list = [pivot_scores, pivot_ls_scores, vote_scores, vote_ls_scores]

mean_scores = [np.mean(x) for x in scores_list]
print(mean_scores)
std_scores = [np.std(x) for x in scores_list]

plot_names = ["Pivot", "PLS", "Vote", "VLS"]
x_pos = np.arange(len(plot_names))

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_scores, yerr=std_scores, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Objective Value')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('DBLP Objective Values, K = 100')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
# plt.savefig('bar_plot_with_error_bars.png')
plt.ylim(550000)
plt.show()
# Out:
# [961869.2, 614600.7, 678375.2, 615476.1]

# %% [markdown]
# ### DBLP Times

# %%
pm5_times = [242.0,121.0,134.0,89.0,84.0,85.0,82.0,90.0,82.0,84.0]
imp5_times = [832.0,806.0,509.0,474.0,468.0,632.0,451.0,512.0,471.0,511.0]

pm10_times = [81.0,82.0,83.0,86.0,97.0,80.0,82.0,121.0,83.0,87.0]
imp10_times = [462.0,463.0,459.0,506.0,478.0,488.0,434.0,485.0,452.0,494.0]

times_list = [pm5_times, imp5_times, pm10_times, imp10_times]
times_list = [[i / 1000 for i in x] for x in times_list]

mean_times = [np.mean(x) for x in times_list]
print(mean_times)

std_times = [np.std(x) for x in times_list]

plot_names = ["Pivot 50", "Vote 50", "Pivot 100", "Vote 100"]
x_pos = np.arange(len(plot_names))

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_times, yerr=std_times, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Time (s)')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('DBLP Times')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
# plt.savefig('bar_plot_with_error_bars.png')
plt.show()
# Out:
# [0.1093, 0.5666, 0.08819999999999999, 0.4721]

# %% [markdown]
# ### YouTube, K = 50

# %%
# New methods
pivot_scores = [3195199,3222972,3225672,3217032,3221679,3248821,3204173,3213175,3232660,3229685]
pivot_ls_scores = [2666998,2666865,2666697,2667341,2666816,2666694,2666612,2666935,2666836,2666810]
vote_scores = [2720070,2720034,2720149,2720331,2720260,2719871,2720129,2720589,2720317,2719822]
vote_ls_scores = [2667803,2667678,2667807,2667677,2667667,2667800,2667703,2667837,2667944,2667930]

scores_list = [pivot_scores, pivot_ls_scores, vote_scores, vote_ls_scores]

mean_scores = [np.mean(x) for x in scores_list]
print(mean_scores)
std_scores = [np.std(x) for x in scores_list]

plot_names = ["Pivot", "PLS", "Vote", "VLS"]
x_pos = np.arange(len(plot_names))

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_scores, yerr=std_scores, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Objective Value')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Youtube Objective Values, K = 50')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
# plt.savefig('bar_plot_with_error_bars.png')
plt.ylim(2500000, 3300000)
plt.show()
# Out:
# [3221106.8, 2666860.4, 2720157.2, 2667784.6]

# %% [markdown]
# ### Youtube, K = 100

# %%
# New methods
pivot_scores = [3373625,3327404,3363526,3354862,3334212,3332883,3322153,3360348,3357222,3367398]
pivot_ls_scores = [2666741,2666820,2666862,2667046,2666990,2666623,2667070,2666664,2666586,2666637]
vote_scores = [2720441,2720333,2720649,2720681,2719972,2720524,2720405,2720537,2720042,2720287]
vote_ls_scores = [2667831,2667769,2668013,2667775,2667958,2667954,2667860,2667879,2668164,2667656]

scores_list = [pivot_scores, pivot_ls_scores, vote_scores, vote_ls_scores]

mean_scores = [np.mean(x) for x in scores_list]
print(mean_scores)
std_scores = [np.std(x) for x in scores_list]

plot_names = ["Pivot", "PLS", "Vote", "VLS"]
x_pos = np.arange(len(plot_names))

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_scores, yerr=std_scores, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Objective Value')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Youtube Objective Values, K = 100')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
# plt.savefig('bar_plot_with_error_bars.png')
plt.ylim(2500000, 3400000)
plt.show()
# Out:
# [3349363.3, 2666803.9, 2720387.1, 2667885.9]

# %% [markdown]
# ### Youtube Times

# %%
pm5_times = [1749.0,836.0,577.0,587.0,564.0,511.0,708.0,689.0,631.0,610.0]
imp5_times = [3154.0,3941.0,2100.0,1985.0,2458.0,1839.0,2714.0,2501.0,2581.0,2121.0]

pm10_times = [775.0,792.0,710.0,774.0,592.0,761.0,584.0,550.0,587.0,555.0]
imp10_times = [2424.0,2854.0,3251.0,2859.0,2481.0,2583.0,2380.0,2047.0,2408.0,2288.0]

times_list = [pm5_times, imp5_times, pm10_times, imp10_times]
times_list = [[i / 1000 for i in x] for x in times_list]

mean_times = [np.mean(x) for x in times_list]
print(mean_times)

std_times = [np.std(x) for x in times_list]

plot_names = ["Pivot 50", "Vote 50", "Pivot 100", "Vote 100"]
x_pos = np.arange(len(plot_names))

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_times, yerr=std_times, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Time (s)')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Youtube Times')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
# plt.savefig('bar_plot_with_error_bars.png')
plt.show()
# Out:
# [0.7462, 2.5393999999999997, 0.6679999999999999, 2.5575]

# %% [markdown]
# ### Livejournal, K = 50

# %%
# New methods
pivot_scores = [39582415,39497482,39658274,39589418,39528088,39604594,39607434,39650131,39633353,39589661]
pivot_ls_scores = [29338823,29338715,29342205,29339839,29340604,29340017,29343087,29337443,29342679,29342091]
vote_scores = [30824349,30820904,30824026,30823082,30824984,30827839,30828010,30822434,30823692,30831367]
vote_ls_scores = [29343916,29345475,29345926,29346004,29344266,29347294,29345881,29344226,29344233,29348384]

scores_list = [pivot_scores, pivot_ls_scores, vote_scores, vote_ls_scores]

mean_scores = [np.mean(x) for x in scores_list]
print(mean_scores)
std_scores = [np.std(x) for x in scores_list]

plot_names = ["Pivot", "PLS", "Vote", "VLS"]
x_pos = np.arange(len(plot_names))

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_scores, yerr=std_scores, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Objective Value')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Livejournal Objective Values, K = 50')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
# plt.savefig('bar_plot_with_error_bars.png')
plt.ylim(25000000)
plt.show()
# Out:
# [39594085.0, 29340550.3, 30825068.7, 29345560.5]

# %% [markdown]
# ### Livejournal, K = 100

# %%
# New methods
pivot_scores = [41328735,41285759,41242644,41228754,41184476,41260053,41338079,41253142,41371684,41252554]
pivot_ls_scores = [29082316,29079616,29076688,29078052,29073423,29077725,29079225,29083428,29079643,29081715]
vote_scores = [30569096,30567961,30570529,30573265,30569657,30576855,30564947,30574375,30565399,30570637]
vote_ls_scores = [29078334,29079527,29076832,29082724,29083006,29079845,29078736,29084845,29078664,29077162]

scores_list = [pivot_scores, pivot_ls_scores, vote_scores, vote_ls_scores]

mean_scores = [np.mean(x) for x in scores_list]
print(mean_scores)
std_scores = [np.std(x) for x in scores_list]

plot_names = ["Pivot", "PLS", "Vote", "VLS"]
x_pos = np.arange(len(plot_names))

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_scores, yerr=std_scores, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Objective Value')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Livejournal Objective Values, K = 100')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
# plt.savefig('bar_plot_with_error_bars.png')
plt.ylim(25000000)
plt.show()
# Out:
# [41274588.0, 29079183.1, 30570272.1, 29079967.5]

# %% [markdown]
# ### Livejournal Times

# %%
pm5_times = [2287.0,2684.0,2468.0,2024.0,2417.0,2084.0,2262.0,1936.0,2092.0,2411.0]
imp5_times = [24421.0,25880.0,23005.0,21101.0,24822.0,21525.0,20684.0,24948.0,20517.0,20554.0]

pm10_times = [2042.0,2450.0,2045.0,2565.0,2636.0,2654.0,2157.0,2883.0,2707.0,1930.0]
imp10_times = [20876.0,21563.0,20546.0,22980.0,30420.0,23859.0,19683.0,25145.0,23827.0,22342.0]

times_list = [pm5_times, imp5_times, pm10_times, imp10_times]
times_list = [[i / 1000 for i in x] for x in times_list]

mean_times = [np.mean(x) for x in times_list]
print(mean_times)

std_times = [np.std(x) for x in times_list]

plot_names = ["Pivot 50", "Vote 50", "Pivot 100", "Vote 100"]
x_pos = np.arange(len(plot_names))

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_times, yerr=std_times, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Time (s)')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Livejournal Times')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
# plt.savefig('bar_plot_with_error_bars.png')
plt.show()
# Out:
# [2.2664999999999997, 22.7457, 2.4069000000000003, 23.1241]

# %% [markdown]
# ### Orkut, K = 50

# %%
# New methods
pivot_scores = [136150601,136212146,136134465,136150432,136180415,136102741,136060488,136183568,136168831,136155701]
pivot_ls_scores = [108433637,108371104,108394344,108299971,108372525,108315163,108332835,108363115,108309643,108278097]
vote_scores = [111670567,111670516,111683722,111666877,111664461,111672779,111648090,111664780,111677802,111665496]
vote_ls_scores = [108194553,108190127,108181829,108180786,108161805,108165978,108148110,108182181,108160413,108189931]

scores_list = [pivot_scores, pivot_ls_scores, vote_scores, vote_ls_scores]

mean_scores = [np.mean(x) for x in scores_list]
print(mean_scores)
std_scores = [np.std(x) for x in scores_list]

plot_names = ["Pivot", "PLS", "Vote", "VLS"]
x_pos = np.arange(len(plot_names))

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_scores, yerr=std_scores, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Objective Value')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Orkut Objective Values, K = 50')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
# plt.savefig('bar_plot_with_error_bars.png')
plt.ylim(100000000, 140000000)
plt.show()
# Out:
# [136149938.8, 108347043.4, 111668509.0, 108175571.3]

# %% [markdown]
# ### Okrut, K = 100

# %%
# New methods
pivot_scores = [145412567,145628895,145412296,145341338,145577483,145332848,145342338,145477632,145518641,145531084]
pivot_ls_scores = [107913513,107906316,107938953,107939489,107892232,107945192,107975718,107937183,107907193,107867612]
vote_scores = [111301659,111293568,111293119,111290898,111295713,111298861,111290588,111304784,111295315,111298621]
vote_ls_scores = [107755344,107764324,107730143,107724365,107727182,107754703,107761909,107761871,107747332,107748189]

scores_list = [pivot_scores, pivot_ls_scores, vote_scores, vote_ls_scores]

mean_scores = [np.mean(x) for x in scores_list]
print(mean_scores)
std_scores = [np.std(x) for x in scores_list]

plot_names = ["Pivot", "PLS", "Vote", "VLS"]
x_pos = np.arange(len(plot_names))

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_scores, yerr=std_scores, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Objective Value')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Orkut Objective Values, K = 100')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
# plt.savefig('bar_plot_with_error_bars.png')
plt.ylim(100000000, 150000000)
plt.show()
# Out:
# [145457512.2, 107922340.1, 111296312.6, 107747536.2]

# %% [markdown]
# ### Orkut Times

# %%
pm5_times = [2780.0,1847.0,1709.0,1740.0,1741.0,1710.0,1726.0,2062.0,2451.0,1684.0]
imp5_times = [65715.0,63729.0,62500.0,59826.0,60804.0,60070.0,58886.0,59867.0,72032.0,63133.0]

pm10_times = [1853.0,1637.0,1956.0,1690.0,1700.0,1772.0,1703.0,1642.0,1680.0,1997.0]
imp10_times = [60204.0,60045.0,60070.0,79703.0,67722.0,67439.0,71556.0,71741.0,70886.0,68625.0]

times_list = [pm5_times, imp5_times, pm10_times, imp10_times]
times_list = [[i / 1000 for i in x] for x in times_list]

mean_times = [np.mean(x) for x in times_list]
print(mean_times)

std_times = [np.std(x) for x in times_list]

plot_names = ["Pivot 50", "Vote 50", "Pivot 100", "Vote 100"]
x_pos = np.arange(len(plot_names))

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_times, yerr=std_times, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Time (s)')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Orkut Times')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
# plt.savefig('bar_plot_with_error_bars.png')
plt.show()
# Out:
# [1.9450000000000003, 62.65620000000001, 1.763, 67.7991]

# %% [markdown]
# ### TEMPLATE

# %%
# New methods
pivot_scores = 
pivot_ls_scores = 
vote_scores = 
vote_ls_scores = 

scores_list = [pivot_scores, pivot_ls_scores, vote_scores, vote_ls_scores]

mean_scores = [np.mean(x) for x in scores_list]
print(mean_scores)
std_scores = [np.std(x) for x in scores_list]

plot_names = ["Pivot", "PLS", "Vote", "VLS"]
x_pos = np.arange(len(plot_names))

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_scores, yerr=std_scores, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Objective Value')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Amazon Objective Values, K = 50')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
# plt.savefig('bar_plot_with_error_bars.png')
plt.show()

# %%
pm5_times = 
imp5_times = 

pm10_times = 
imp10_times = 

times_list = [pm5_times, imp5_times, pm10_times, imp10_times]
times_list = [[i / 1000 for i in x] for x in times_list]

mean_times = [np.mean(x) for x in times_list]
print(mean_times)

std_times = [np.std(x) for x in times_list]

plot_names = ["Pivot 50", "Vote 50", "Pivot 100", "Vote 100"]
x_pos = np.arange(len(plot_names))

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_times, yerr=std_times, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Time (s)')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Amazon Times')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
# plt.savefig('bar_plot_with_error_bars.png')
plt.show()
