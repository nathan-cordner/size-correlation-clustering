# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Gym

# %%
# Old methods

alg1_4_scores = [373,400,423,374,383,409,384,385,412,367]
alg1_2_scores = [382,368,399,395,400,393,384,397,385,417]
alg1_1_scores = [395,405,416,393,402,416,423,407,412,440]
alg2_scores = [422,417,401,398,400,429,413,436,419,429]

# New methods
pivot_scores = [410,403,403,410,407,423,396,407,416,402]
pivot_ls_scores = [372,369,372,366,369,374,370,366,370,361]
vote_scores = [357,334,360,347,362,363,356,348,378,383]
vote_ls_scores = [348,327,353,340,352,357,349,338,356,360]
order_vote_scores = [292,292,292,292,292,292,292,292,292,292]
order_vote_ls_scores = [276,276,276,277,275,275,277,276,276,275]

scores_list = [alg1_4_scores, alg1_2_scores, alg1_1_scores, alg2_scores]
scores_list += [pivot_scores, pivot_ls_scores, vote_scores, vote_ls_scores, order_vote_scores, order_vote_ls_scores]

mean_scores = [np.mean(x) for x in scores_list]
print(mean_scores)
std_scores = [np.std(x) for x in scores_list]

plot_names = ["LP1(.5)", "LP1(.3)", "LP1(.1)", "LP2", "Pivot", "PLS", "Vote", "VLS", "Order", "OLS"]
x_pos = np.arange(len(plot_names))

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_scores, yerr=std_scores, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Objective Value')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Gym 1 Objective Values')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
# plt.savefig('bar_plot_with_error_bars.png')
plt.ylim(270, 435)
plt.show()

### --- ###

# Old methods

alg1_4_scores = [365,366,370,364,372,370,371,390,411,369]
alg1_2_scores = [382,370,390,387,376,388,379,391,360,402]
alg1_1_scores = [399,392,383,379,384,400,396,390,395,394]
alg2_scores = [423,432,411,427,414,436,421,409,436,436]

# New methods
pivot_scores = [413,422,417,405,429,414,407,413,423,406]
pivot_ls_scores = [384,374,370,367,384,376,376,389,398,386]
vote_scores = [375,391,359,361,374,379,377,373,350,375]
vote_ls_scores = [372,370,357,353,367,368,366,357,338,361]
order_vote_scores = [326,326,326,326,326,326,326,326,326,326]
order_vote_ls_scores = [313,313,312,313,313,312,312,312,312,313]

scores_list = [alg1_4_scores, alg1_2_scores, alg1_1_scores, alg2_scores]
scores_list += [pivot_scores, pivot_ls_scores, vote_scores, vote_ls_scores, order_vote_scores, order_vote_ls_scores]

mean_scores = [np.mean(x) for x in scores_list]
print(mean_scores)
std_scores = [np.std(x) for x in scores_list]

plot_names = ["LP1(.5)", "LP1(.3)", "LP1(.1)", "LP2", "Pivot", "PLS", "Vote", "VLS", "Order", "OLS"]
x_pos = np.arange(len(plot_names))

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_scores, yerr=std_scores, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Objective Value')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Gym 2 Objective Values')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
# plt.savefig('bar_plot_with_error_bars.png')
plt.ylim(300, 440)
plt.show()

### --- ###

# Old methods

alg1_4_scores = [340,350,347,364,415,358,354,346,384,366]
alg1_2_scores = [369,365,369,357,385,365,381,357,388,384]
alg1_1_scores = [402,386,379,393,379,383,379,373,395,382]
alg2_scores = [389,420,421,421,424,431,439,421,418,420]

# New methods
pivot_scores = [391,385,399,395,394,390,406,403,406,391]
pivot_ls_scores = [360,345,365,352,356,346,358,358,359,365]
vote_scores = [363,356,340,374,373,363,368,370,369,383]
vote_ls_scores = [345,346,327,343,348,349,346,338,352,347]
order_vote_scores = [346,346,346,346,346,346,346,346,346,346]
order_vote_ls_scores = [325,326,327,325,325,325,327,328,328,330]

scores_list = [alg1_4_scores, alg1_2_scores, alg1_1_scores, alg2_scores]
scores_list += [pivot_scores, pivot_ls_scores, vote_scores, vote_ls_scores, order_vote_scores, order_vote_ls_scores]

mean_scores = [np.mean(x) for x in scores_list]
print(mean_scores)
std_scores = [np.std(x) for x in scores_list]

plot_names = ["LP1(.5)", "LP1(.3)", "LP1(.1)", "LP2", "Pivot", "PLS", "Vote", "VLS", "Order", "OLS"]
x_pos = np.arange(len(plot_names))

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_scores, yerr=std_scores, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Objective Value')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Gym 3 Objective Values')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
# plt.savefig('bar_plot_with_error_bars.png')
plt.ylim(320, 440)
plt.show()
# Out:
# [391.0, 392.0, 410.9, 416.4, 407.7, 368.9, 358.8, 348.0, 292.0, 275.9]
# [374.8, 382.5, 391.2, 424.5, 414.9, 380.4, 371.4, 360.9, 326.0, 312.5]
# [362.4, 372.0, 385.1, 420.4, 396.0, 356.4, 365.9, 344.1, 346.0, 326.6]

# %% [markdown]
# ### Cora

# %%
# Old methods

alg1_4_scores = [1120,1077,1121,1205,1072,1061,1332,1256,1074,1102]
alg1_2_scores = [1313,1245,1336,1202,1277,1213,1224,1312,1318,1262]
alg1_1_scores = [1418,1420,1393,1429,1426,1426,1391,1368,1387,1261]
alg2_scores = [1537,1543,1550,1541,1549,1540,1529,1539,1547,1533]

# New methods
pivot_scores = [1420,1438,1459,1436,1449,1402,1449,1391,1409,1434]
pivot_ls_scores = [1358,1360,1369,1357,1402,1385,1399,1359,1367,1390]
vote_scores = [1107,1246,1248,1239,1186,1324,1194,1149,1208,1170]
vote_ls_scores = [1102,1234,1248,1233,1184,1302,1184,1133,1197,1123]
order_vote_scores = [981,981,981,981,981,981,981,981,981,981]
order_vote_ls_scores = [981,981,979,979,981,979,979,979,979,979]

scores_list = [alg1_4_scores, alg1_2_scores, alg1_1_scores, alg2_scores]
scores_list += [pivot_scores, pivot_ls_scores, vote_scores, vote_ls_scores, order_vote_scores, order_vote_ls_scores]

mean_scores = [np.mean(x) for x in scores_list]
print(mean_scores)
std_scores = [np.std(x) for x in scores_list]

plot_names = ["LP1(.5)", "LP1(.3)", "LP1(.1)", "LP2", "Pivot", "PLS", "Vote", "VLS", "Order", "OLS"]
x_pos = np.arange(len(plot_names))

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_scores, yerr=std_scores, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Objective Value')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Cora 1 Objective Values')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
# plt.savefig('bar_plot_with_error_bars.png')
plt.ylim(950, 1560)
plt.show()

### --- ###

# Old methods

alg1_4_scores = [1218,1326,912,1214,1280,1385,1254,1347,1055,1257]
alg1_2_scores = [1461,1355,1277,1288,1238,1305,1332,1439,1353,1389]
alg1_1_scores = [1259,1018,1434,1212,1445,1426,1293,1434,1413,1284]
alg2_scores = [1547,1539,1534,1550,1546,1539,1541,1550,1554,1541]

# New methods
pivot_scores = [1436,1443,1434,1397,1443,1435,1423,1444,1417,1433]
pivot_ls_scores = [1349,1376,1418,1363,1393,1408,1383,1402,1396,1406]
vote_scores = [1095,1274,1231,1138,1380,1110,1174,1112,1247,1201]
vote_ls_scores = [1089,1261,1218,1125,1341,1100,1170,1105,1235,1190]
order_vote_scores = [1119,1119,1119,1119,1119,1119,1119,1119,1119,1119]
order_vote_ls_scores = [1096,1095,1095,1096,1096,1096,1095,1096,1095,1096]

scores_list = [alg1_4_scores, alg1_2_scores, alg1_1_scores, alg2_scores]
scores_list += [pivot_scores, pivot_ls_scores, vote_scores, vote_ls_scores, order_vote_scores, order_vote_ls_scores]

mean_scores = [np.mean(x) for x in scores_list]
print(mean_scores)
std_scores = [np.std(x) for x in scores_list]

plot_names = ["LP1(.5)", "LP1(.3)", "LP1(.1)", "LP2", "Pivot", "PLS", "Vote", "VLS", "Order", "OLS"]
x_pos = np.arange(len(plot_names))

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_scores, yerr=std_scores, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Objective Value')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Cora 2 Objective Values')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
# plt.savefig('bar_plot_with_error_bars.png')
plt.ylim(1050, 1560)
plt.show()


### --- ###

# Old methods

alg1_4_scores = [1344,1376,1412,1361,1368,1250,1144,1102,1367,1371]
alg1_2_scores = [1308,1191,1164,1337,1438,1079,1233,1337,1424,1406]
alg1_1_scores = [1352,1167,1273,1424,1205,1307,1250,1337,1367,1391]
alg2_scores = [1539,1538,1536,1549,1558,1537,1544,1527,1551,1536]

# New methods
pivot_scores = [1399,1409,1458,1391,1398,1440,1422,1423,1456,1417]
pivot_ls_scores = [1341,1374,1389,1371,1344,1374,1361,1369,1401,1387]
vote_scores = [1180,1072,1123,1277,1200,1222,1127,1164,1259,1080]
vote_ls_scores = [1172,1071,1118,1271,1195,1216,1121,1148,1238,1071]
order_vote_scores = [1010,1010,1010,1010,1010,1010,1010,1010,1010,1010]
order_vote_ls_scores = [1006,1006,1006,1006,1006,1007,1006,1006,1006,1006]

scores_list = [alg1_4_scores, alg1_2_scores, alg1_1_scores, alg2_scores]
scores_list += [pivot_scores, pivot_ls_scores, vote_scores, vote_ls_scores, order_vote_scores, order_vote_ls_scores]

mean_scores = [np.mean(x) for x in scores_list]
print(mean_scores)
std_scores = [np.std(x) for x in scores_list]

plot_names = ["LP1(.5)", "LP1(.3)", "LP1(.1)", "LP2", "Pivot", "PLS", "Vote", "VLS", "Order", "OLS"]
x_pos = np.arange(len(plot_names))

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_scores, yerr=std_scores, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Objective Value')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Cora 3 Objective Values')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
# plt.savefig('bar_plot_with_error_bars.png')
plt.ylim(1000, 1560)
plt.show()
# Out:
# [1142.0, 1270.2, 1391.9, 1540.8, 1428.7, 1374.6, 1207.1, 1194.0, 981.0, 979.6]
# [1224.8, 1343.7, 1321.8, 1544.1, 1430.5, 1389.4, 1196.2, 1183.4, 1119.0, 1095.6]
# [1309.5, 1291.7, 1307.3, 1541.5, 1421.3, 1371.1, 1170.4, 1162.1, 1010.0, 1006.1]

# %% [markdown]
# ### Captchas

# %%
# Old methods

alg1_4_scores = [272,309,284,294,263,262,325,312,289,344]
alg1_2_scores = [352,340,384,350,354,380,390,338,361,342]
alg1_1_scores = [392,342,354,405,378,381,386,401,314,388]
alg2_scores = [419,442,426,434,418,403,382,395,399,448]

# New methods
pivot_scores = [452,455,454,461,465,453,450,464,452,456]
pivot_ls_scores = [437,441,430,433,437,438,438,434,434,442]
vote_scores = [417,435,420,414,407,445,405,410,413,406]
vote_ls_scores = [405,422,405,406,402,417,394,401,407,401]
order_vote_scores = [326,326,326,326,326,326,326,326,326,326]
order_vote_ls_scores = [325,325,325,325,325,325,325,325,325,325]

scores_list = [alg1_4_scores, alg1_2_scores, alg1_1_scores, alg2_scores]
scores_list += [pivot_scores, pivot_ls_scores, vote_scores, vote_ls_scores, order_vote_scores, order_vote_ls_scores]

mean_scores = [np.mean(x) for x in scores_list]
print(mean_scores)
std_scores = [np.std(x) for x in scores_list]

plot_names = ["LP1(.5)", "LP1(.3)", "LP1(.1)", "LP2", "Pivot", "PLS", "Vote", "VLS", "Order", "OLS"]
x_pos = np.arange(len(plot_names))

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_scores, yerr=std_scores, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Objective Value')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Captchas 1 Objective Values')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
# plt.savefig('bar_plot_with_error_bars.png')
plt.ylim(250)
plt.show()

### --- ###

# Old methods

alg1_4_scores = [326,305,302,330,340,314,263,269,287,301]
alg1_2_scores = [366,365,380,320,320,373,342,355,348,313]
alg1_1_scores = [368,356,380,399,397,402,416,351,389,361]
alg2_scores = [479,415,433,449,457,448,469,438,450,462]

# New methods
pivot_scores = [447,442,449,458,450,448,445,456,445,450]
pivot_ls_scores = [433,427,440,443,441,438,438,426,428,440]
vote_scores = [408,411,414,421,416,420,409,413,408,429]
vote_ls_scores = [403,400,408,406,410,407,402,405,400,416]
order_vote_scores = [336,336,336,336,336,336,336,336,336,336]
order_vote_ls_scores = [330,331,330,330,330,331,330,330,331,331]

scores_list = [alg1_4_scores, alg1_2_scores, alg1_1_scores, alg2_scores]
scores_list += [pivot_scores, pivot_ls_scores, vote_scores, vote_ls_scores, order_vote_scores, order_vote_ls_scores]

mean_scores = [np.mean(x) for x in scores_list]
print(mean_scores)
std_scores = [np.std(x) for x in scores_list]

plot_names = ["LP1(.5)", "LP1(.3)", "LP1(.1)", "LP2", "Pivot", "PLS", "Vote", "VLS", "Order", "OLS"]
x_pos = np.arange(len(plot_names))

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_scores, yerr=std_scores, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Objective Value')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Captchas 2 Objective Values')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
# plt.savefig('bar_plot_with_error_bars.png')
plt.ylim(250)
plt.show()


### --- ###

# Old methods

alg1_4_scores = [292,326,367,357,345,365,322,379,321,358]
alg1_2_scores = [372,363,381,364,401,349,411,399,369,382]
alg1_1_scores = [414,412,418,432,399,436,433,437,414,408]
alg2_scores = [476,473,452,503,487,428,484,460,424,426]

# New methods
pivot_scores = [470,475,467,476,469,466,462,466,475,471]
pivot_ls_scores = [457,446,452,455,459,463,447,452,462,453]
vote_scores = [448,422,441,453,423,428,430,441,426,433]
vote_ls_scores = [441,410,434,442,418,421,418,432,415,431]
order_vote_scores = [409,409,409,409,409,409,409,409,409,409]
order_vote_ls_scores = [395,395,395,395,395,395,395,395,395,395]

scores_list = [alg1_4_scores, alg1_2_scores, alg1_1_scores, alg2_scores]
scores_list += [pivot_scores, pivot_ls_scores, vote_scores, vote_ls_scores, order_vote_scores, order_vote_ls_scores]

mean_scores = [np.mean(x) for x in scores_list]
print(mean_scores)
std_scores = [np.std(x) for x in scores_list]

plot_names = ["LP1(.5)", "LP1(.3)", "LP1(.1)", "LP2", "Pivot", "PLS", "Vote", "VLS", "Order", "OLS"]
x_pos = np.arange(len(plot_names))

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_scores, yerr=std_scores, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Objective Value')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Captchas 3 Objective Values')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
# plt.savefig('bar_plot_with_error_bars.png')
plt.ylim(250)
plt.show()
# Out:
# [295.4, 359.1, 374.1, 416.6, 456.2, 436.4, 417.2, 406.0, 326.0, 325.0]
# [303.7, 348.2, 381.9, 450.0, 449.0, 435.4, 414.9, 405.7, 336.0, 330.4]
# [343.2, 379.1, 420.3, 461.3, 469.7, 454.6, 434.5, 426.2, 409.0, 395.0]

# %% [markdown]
# ### Landmarks

# %%
# Old methods

alg1_4_scores = [29661,29101,29495,29607,29565,29590,29447,29724,29602,29593]
alg1_2_scores = [29352,29593,29503,29593,29377,29553,29451,29464,29495,29542]
alg1_1_scores = [29433,29667,29317,29369,29597,29499,29618,29194,29537,29715]
alg2_scores = [29607,29552,29789,29691,29773,29605,29637,29677,29417,29801]

# New methods
pivot_scores = [27977,27982,28369,28189,28192,28217,28335,28134,28030,28020]
pivot_ls_scores = [27708,27698,28124,27960,28057,28072,28082,27330,27752,27906]
vote_scores = [20796,18613,22849,21739,22954,19357,19167,21263,19457,22233]
vote_ls_scores = [20729,18600,22821,21479,22920,19355,19073,21236,19447,22218]
order_vote_scores = [12212,12212,12212,12212,12212,12212,12212,12212,12212,12212]
order_vote_ls_scores = [12212,12212,12212,12212,12212,12212,12212,12212,12212,12212]

scores_list = [alg1_4_scores, alg1_2_scores, alg1_1_scores, alg2_scores]
scores_list += [pivot_scores, pivot_ls_scores, vote_scores, vote_ls_scores, order_vote_scores, order_vote_ls_scores]

mean_scores = [np.mean(x) for x in scores_list]
print(mean_scores)
std_scores = [np.std(x) for x in scores_list]

plot_names = ["LP1(.5)", "LP1(.3)", "LP1(.1)", "LP2", "Pivot", "PLS", "Vote", "VLS", "Order", "OLS"]
x_pos = np.arange(len(plot_names))

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_scores, yerr=std_scores, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Objective Value')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Landmarks 1 Objective Values')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
# plt.savefig('bar_plot_with_error_bars.png')
plt.ylim(10000)
plt.show()

### --- ###

# Old methods

alg1_4_scores = [29600,29224,29600,29605,29372,29545,28993,29377,29539,29654]
alg1_2_scores = [28924,29155,29651,29045,29160,29074,29607,29561,29679,29587]
alg1_1_scores = [29416,29024,29400,29500,29288,29292,29384,29465,29332,29461]
alg2_scores = [29577,29557,29745,29676,29627,29211,29603,28656,29257,29774]

# New methods
pivot_scores = [28535,28361,28510,28163,28321,28076,28448,28205,28250,28226]
pivot_ls_scores = [28035,28219,28409,28020,28175,27911,28319,28104,28120,27816]
vote_scores = [18619,18475,22542,20681,23019,21167,20189,20897,21528,18822]
vote_ls_scores = [18558,18413,22540,20663,22944,21150,20173,20888,21516,18800]
order_vote_scores = [18595,18595,18595,18595,18595,18595,18595,18595,18595,18595]
order_vote_ls_scores = [18511,18511,18511,18511,18511,18511,18511,18511,18511,18511]

scores_list = [alg1_4_scores, alg1_2_scores, alg1_1_scores, alg2_scores]
scores_list += [pivot_scores, pivot_ls_scores, vote_scores, vote_ls_scores, order_vote_scores, order_vote_ls_scores]

mean_scores = [np.mean(x) for x in scores_list]
print(mean_scores)
std_scores = [np.std(x) for x in scores_list]

plot_names = ["LP1(.5)", "LP1(.3)", "LP1(.1)", "LP2", "Pivot", "PLS", "Vote", "VLS", "Order", "OLS"]
x_pos = np.arange(len(plot_names))

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_scores, yerr=std_scores, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Objective Value')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Landmarks 2 Objective Values')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
# plt.savefig('bar_plot_with_error_bars.png')
plt.ylim(15000)
plt.show()


### --- ###

# Old methods

alg1_4_scores = [29123,29452,29629,29488,29382,29354,29578,29453,29371,29486]
alg1_2_scores = [29315,29547,29699,29625,29371,29693,29557,29611,29685,29730]
alg1_1_scores = [29563,29411,29539,29660,29555,29722,29548,29534,29627,29300]
alg2_scores = [29379,29818,29349,29543,29739,29628,29715,29716,29743,29603]

# New methods
pivot_scores = [28618,28621,28396,28550,28604,28517,28637,28674,28621,28485]
pivot_ls_scores = [28380,28355,27942,28407,28472,28419,28338,28563,28419,28279]
vote_scores = [23534,20408,22241,21257,21327,18796,21295,20644,23418,20980]
vote_ls_scores = [23498,20360,22159,21218,21196,18777,21290,20607,23328,20915]
order_vote_scores = [11320,11320,11320,11320,11320,11320,11320,11320,11320,11320]
order_vote_ls_scores = [10908,10910,10910,10908,10910,10910,10910,10910,10909,10908]

scores_list = [alg1_4_scores, alg1_2_scores, alg1_1_scores, alg2_scores]
scores_list += [pivot_scores, pivot_ls_scores, vote_scores, vote_ls_scores, order_vote_scores, order_vote_ls_scores]

mean_scores = [np.mean(x) for x in scores_list]
print(mean_scores)
std_scores = [np.std(x) for x in scores_list]

plot_names = ["LP1(.5)", "LP1(.3)", "LP1(.1)", "LP2", "Pivot", "PLS", "Vote", "VLS", "Order", "OLS"]
x_pos = np.arange(len(plot_names))

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_scores, yerr=std_scores, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Objective Value')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Landmarks 3 Objective Values')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
# plt.savefig('bar_plot_with_error_bars.png')
plt.ylim(10000)
plt.show()
# Out:
# [29538.5, 29492.3, 29494.6, 29654.9, 28144.5, 27868.9, 20842.8, 20787.8, 12212.0, 12212.0]
# [29450.9, 29344.3, 29356.2, 29468.3, 28309.5, 28112.8, 20593.9, 20564.5, 18595.0, 18511.0]
# [29431.6, 29583.3, 29545.9, 29623.3, 28572.3, 28357.4, 21390.0, 21334.8, 11320.0, 10909.3]

# %% [markdown]
# ### Allsports

# %%
# Old methods

alg1_4_scores = [36,33,36,37,34,36,35,36,36,35]
alg1_2_scores = [38,35,38,36,38,38,37,39,39,37]
alg1_1_scores = [39,37,36,36,39,39,36,35,37,36]
alg2_scores = [39,39,39,39,37,40,39,37,40,37]

# New methods
pivot_scores = [54,56,55,56,56,56,55,56,56,55]
pivot_ls_scores = [54,56,55,55,55,55,54,55,56,54]
vote_scores = [54,54,56,56,56,55,56,56,54,55]
vote_ls_scores = [54,54,55,54,54,55,56,54,54,55]
order_vote_scores = [54,54,54,54,54,54,54,54,54,54]
order_vote_ls_scores = [54,54,54,54,54,54,54,54,54,54]

scores_list = [alg1_4_scores, alg1_2_scores, alg1_1_scores, alg2_scores]
scores_list += [pivot_scores, pivot_ls_scores, vote_scores, vote_ls_scores, order_vote_scores, order_vote_ls_scores]

mean_scores = [np.mean(x) for x in scores_list]
print(mean_scores)
std_scores = [np.std(x) for x in scores_list]

plot_names = ["LP1(.5)", "LP1(.3)", "LP1(.1)", "LP2", "Pivot", "PLS", "Vote", "VLS", "Order", "OLS"]
x_pos = np.arange(len(plot_names))

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_scores, yerr=std_scores, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Objective Value')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Allsports 1 Objective Values')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
# plt.savefig('bar_plot_with_error_bars.png')
plt.ylim(30)
plt.show()

### --- ###

# Old methods

alg1_4_scores = [33,38,34,35,35,37,36,38,35,37]
alg1_2_scores = [37,35,37,38,35,36,36,37,33,35]
alg1_1_scores = [37,38,37,39,39,31,35,36,35,37]
alg2_scores = [38,38,37,38,40,40,38,40,37,38]

# New methods
pivot_scores = [56,56,57,56,56,56,56,56,56,56]
pivot_ls_scores = [56,56,56,56,56,56,56,56,56,56]
vote_scores = [56,56,56,56,56,56,56,57,56,54]
vote_ls_scores = [56,56,56,56,56,56,56,56,56,54]
order_vote_scores = [54,54,54,54,54,54,54,54,54,54]
order_vote_ls_scores = [54,54,54,54,54,54,54,54,54,54]

scores_list = [alg1_4_scores, alg1_2_scores, alg1_1_scores, alg2_scores]
scores_list += [pivot_scores, pivot_ls_scores, vote_scores, vote_ls_scores, order_vote_scores, order_vote_ls_scores]

mean_scores = [np.mean(x) for x in scores_list]
print(mean_scores)
std_scores = [np.std(x) for x in scores_list]

plot_names = ["LP1(.5)", "LP1(.3)", "LP1(.1)", "LP2", "Pivot", "PLS", "Vote", "VLS", "Order", "OLS"]
x_pos = np.arange(len(plot_names))

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_scores, yerr=std_scores, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Objective Value')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Allsports 2 Objective Values')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
# plt.savefig('bar_plot_with_error_bars.png')
plt.ylim(30)
plt.show()


### --- ###

# Old methods

alg1_4_scores = [36,33,35,34,36,35,35,36,35,36]
alg1_2_scores = [35,37,35,35,37,37,35,37,37,37]
alg1_1_scores = [35,37,37,35,35,37,35,37,37,37]
alg2_scores = [38,39,38,39,38,35,39,37,40,40]

# New methods
pivot_scores = [52,52,52,52,52,52,55,54,52,52]
pivot_ls_scores = [52,52,52,52,52,52,52,52,52,52]
vote_scores = [54,50,51,52,51,54,52,54,52,53]
vote_ls_scores = [52,50,51,52,51,52,51,52,52,52]
order_vote_scores = [50,50,50,50,50,50,50,50,50,50]
order_vote_ls_scores = [50,50,50,50,50,50,50,50,50,50]

scores_list = [alg1_4_scores, alg1_2_scores, alg1_1_scores, alg2_scores]
scores_list += [pivot_scores, pivot_ls_scores, vote_scores, vote_ls_scores, order_vote_scores, order_vote_ls_scores]

mean_scores = [np.mean(x) for x in scores_list]
print(mean_scores)
std_scores = [np.std(x) for x in scores_list]

plot_names = ["LP1(.5)", "LP1(.3)", "LP1(.1)", "LP2", "Pivot", "PLS", "Vote", "VLS", "Order", "OLS"]
x_pos = np.arange(len(plot_names))

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_scores, yerr=std_scores, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Objective Value')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Allsports 3 Objective Values')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
# plt.savefig('bar_plot_with_error_bars.png')
plt.ylim(30)
plt.show()
# Out:
# [35.4, 37.5, 37.0, 38.6, 55.5, 54.9, 55.2, 54.5, 54.0, 54.0]
# [35.8, 35.9, 36.4, 38.4, 56.1, 56.0, 55.9, 55.8, 54.0, 54.0]
# [35.1, 36.2, 36.2, 38.3, 52.5, 52.0, 52.3, 51.5, 50.0, 50.0]
