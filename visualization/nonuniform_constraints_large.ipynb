# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Amazon

# %%
# New methods
pivot_scores = [812149,812203,812243,812392,812159,812359,812638,812470,812779,812627]
pivot_ls_scores = [771359,771194,771449,771440,771551,771380,771261,771436,771390,771446]
vote_scores = [785186,785508,785392,785325,785301,785375,785615,785435,785560,785635]
vote_ls_scores = [763269,763556,763503,763716,763461,763631,763701,763471,763861,763613]
order_vote_scores = [755246,755215,755190,755363,755316,755237,755211,755298,755410,755125]
order_vote_ls_scores = [743348,743332,743288,743414,743405,743312,743365,743491,743321,743191]

scores_list = [pivot_scores, pivot_ls_scores, vote_scores, vote_ls_scores, order_vote_scores, order_vote_ls_scores]

mean_scores = [np.mean(x) for x in scores_list]
print(mean_scores)
std_scores = [np.std(x) for x in scores_list]

plot_names = ["Pivot", "PLS", "Vote", "VLS", "Order", "OLS"]
x_pos = np.arange(len(plot_names))

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_scores, yerr=std_scores, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Objective Value')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Amazon Objective Values')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
plt.ylim(720000, 820000)
plt.show()

## PERCENT IMPROVEMENTS ##

baseline = np.mean(pivot_scores)
improvement = [100.0 * (baseline - np.mean(i)) / baseline for i in scores_list]
print(improvement)

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, improvement, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Percent Improvement')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Amazon Objective Values')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
plt.show()

## RUNNING TIMES ##

# New methods
pivot_times = [252.0,168.0,227.0,176.0,212.0,187.0,261.0,166.0,191.0,180.0]
vote_times = [722.0,572.0,561.0,539.0,636.0,598.0,799.0,528.0,596.0,654.0]
order_times = [1024.0,710.0,693.0,694.0,563.0,661.0,532.0,526.0,554.0,520.0]

times_list = [pivot_times, vote_times, order_times]
times_list = [[i / 1000 for i in x] for x in times_list]

mean_times = [np.mean(x) for x in times_list]
print(mean_times)

std_times = [np.std(x) for x in times_list]

plot_names = ["Pivot", "Vote", "Order"]
x_pos = np.arange(len(plot_names))


# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_times, yerr=std_times, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Time (s)')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Amazon Times')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
plt.show()

"""

### --- ###

# New methods
pivot_scores = [812355,812572,812558,812371,812970,812407,812508,812293,812566,812364]
pivot_ls_scores = [771171,771210,771075,771214,771340,771488,771401,771257,771262,771169]
vote_scores = [785217,785510,785078,785232,785344,785865,784743,785298,785383,785361]
vote_ls_scores = [763475,763408,763477,763592,763582,763710,763316,763384,763596,763561]
order_vote_scores = [755233,755408,755314,755377,755376,755407,755293,755348,755236,755201]
order_vote_ls_scores = [743288,743412,743330,743382,743422,743388,743339,743334,743345,743452]

scores_list = [pivot_scores, pivot_ls_scores, vote_scores, vote_ls_scores, order_vote_scores, order_vote_ls_scores]

mean_scores = [np.mean(x) for x in scores_list]
print(mean_scores)
std_scores = [np.std(x) for x in scores_list]

plot_names = ["Pivot", "PLS", "Vote", "VLS", "Order", "OLS"]
x_pos = np.arange(len(plot_names))

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_scores, yerr=std_scores, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Objective Value')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Amazon 2 Objective Values')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
plt.ylim(720000, 820000)
plt.show()


### --- ###

# New methods
pivot_scores = [812346,812777,812394,811967,812358,812358,812794,812419,812758,812249]
pivot_ls_scores = [771271,771428,771441,771269,771591,771173,771410,771426,771494,771359]
vote_scores = [785559,785753,785577,785555,785364,785442,785183,785822,785952,785736]
vote_ls_scores = [763571,763748,763775,763443,763422,763729,763609,763788,763604,763791]
order_vote_scores = [754739,754610,754822,754914,754795,754792,754633,754816,754744,754753]
order_vote_ls_scores = [743018,742940,743052,743091,743108,743008,743004,742926,743077,742896]

scores_list = [pivot_scores, pivot_ls_scores, vote_scores, vote_ls_scores, order_vote_scores, order_vote_ls_scores]

mean_scores = [np.mean(x) for x in scores_list]
print(mean_scores)
std_scores = [np.std(x) for x in scores_list]

plot_names = ["Pivot", "PLS", "Vote", "VLS", "Order", "OLS"]
x_pos = np.arange(len(plot_names))

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_scores, yerr=std_scores, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Objective Value')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Amazon 3 Objective Values')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
plt.ylim(720000, 820000)
plt.show()
"""
# Out:
# [812401.9, 771390.6, 785433.2, 763578.2, 755261.1, 743346.7]
# [0.0, 5.04815412174689, 3.319625421850942, 6.009796382800197, 7.033563067737784, 8.500127830818721]
# [0.202, 0.6205, 0.6477]
# ...

# %% [markdown]
# ### DBLP

# %%
# New methods
pivot_scores = [917968,918978,918337,917506,918444,918772,918260,918048,917949,917834]
pivot_ls_scores = [870329,870544,870586,870452,870404,870595,870462,870146,870423,870143]
vote_scores = [860068,861860,861677,860287,861125,862061,860355,860582,860519,861059]
vote_ls_scores = [837162,838873,838410,837313,837960,839076,837015,837326,837402,838355]
order_vote_scores = [783674,783237,783586,783401,783452,783584,784121,783510,783542,783820]
order_vote_ls_scores = [773843,773503,773779,773657,773632,773813,774241,773588,773638,773697]

scores_list = [pivot_scores, pivot_ls_scores, vote_scores, vote_ls_scores, order_vote_scores, order_vote_ls_scores]

mean_scores = [np.mean(x) for x in scores_list]
print(mean_scores)
std_scores = [np.std(x) for x in scores_list]

plot_names = ["Pivot", "PLS", "Vote", "VLS", "Order", "OLS"]
x_pos = np.arange(len(plot_names))

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_scores, yerr=std_scores, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Objective Value')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('DBLP Objective Values')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
plt.ylim(750000, 925000)
plt.show()

## PERCENT IMPROVEMENTS ##

baseline = np.mean(pivot_scores)
improvement = [100.0 * (baseline - np.mean(i)) / baseline for i in scores_list]
print(improvement)

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, improvement, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Percent Improvement')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('DBLP Objective Values')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
plt.show()

## RUNNING TIMES ##

# New methods
pivot_times = [230.0,178.0,163.0,191.0,163.0,136.0,146.0,143.0,146.0,146.0]
vote_times = [776.0,885.0,545.0,616.0,532.0,504.0,541.0,543.0,550.0,529.0]
order_times = [1157.0,454.0,538.0,445.0,438.0,490.0,438.0,464.0,431.0,428.0]

times_list = [pivot_times, vote_times, order_times]
times_list = [[i / 1000 for i in x] for x in times_list]

mean_times = [np.mean(x) for x in times_list]
print(mean_times)

std_times = [np.std(x) for x in times_list]

plot_names = ["Pivot", "Vote", "Order"]
x_pos = np.arange(len(plot_names))


# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_times, yerr=std_times, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Time (s)')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('DBLP Times')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
plt.show()

"""

### --- ###

# New methods
pivot_scores = [917291,917945,918119,917474,917782,917997,917702,917319,917514,917808]
pivot_ls_scores = [869974,870725,870513,870360,869723,870593,870575,870925,870596,870546]
vote_scores = [861400,861008,859898,861182,860819,860834,861581,860270,859465,861061]
vote_ls_scores = [838473,838397,837016,838454,837459,838043,838889,837438,836982,838259]
order_vote_scores = [782432,782471,782263,782827,782661,782738,782844,782562,782537,782316]
order_vote_ls_scores = [772627,772723,772299,772932,772902,773001,773015,772758,772748,772612]

scores_list = [pivot_scores, pivot_ls_scores, vote_scores, vote_ls_scores, order_vote_scores, order_vote_ls_scores]

mean_scores = [np.mean(x) for x in scores_list]
print(mean_scores)
std_scores = [np.std(x) for x in scores_list]

plot_names = ["Pivot", "PLS", "Vote", "VLS", "Order", "OLS"]
x_pos = np.arange(len(plot_names))

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_scores, yerr=std_scores, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Objective Value')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('DBLP 2 Objective Values')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
plt.ylim(750000, 925000)
plt.show()



### --- ###

# New methods
pivot_scores = [918121,917577,918603,918777,918527,918480,918626,917702,917893,918548]
pivot_ls_scores = [870452,870331,870826,870841,870289,870630,871095,870452,870256,870625]
vote_scores = [859864,861250,862073,861495,861290,862847,860422,860967,861022,862637]
vote_ls_scores = [837134,838468,839005,838584,838333,839754,837654,837744,837889,839255]
order_vote_scores = [783851,783931,784338,783793,783658,783481,783387,783654,783814,783731]
order_vote_ls_scores = [774125,774149,774610,774081,773891,773919,773683,773916,774065,773919]

scores_list = [pivot_scores, pivot_ls_scores, vote_scores, vote_ls_scores, order_vote_scores, order_vote_ls_scores]

mean_scores = [np.mean(x) for x in scores_list]
print(mean_scores)
std_scores = [np.std(x) for x in scores_list]

plot_names = ["Pivot", "PLS", "Vote", "VLS", "Order", "OLS"]
x_pos = np.arange(len(plot_names))

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_scores, yerr=std_scores, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Objective Value')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('DBLP 3 Objective Values')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
plt.ylim(750000, 925000)
plt.show()
"""
# Out:
# [918209.6, 870408.4, 860959.3, 837889.2, 783592.7, 773739.1]
# [0.0, 5.205913769579403, 6.234992533295222, 8.747501659751762, 14.66080293649729, 15.733934822724573]
# [0.16419999999999998, 0.6021, 0.5283]
# ...

# %% [markdown]
# ### Youtube

# %%
# New methods
pivot_scores = [2851630,2850580,2850428,2850111,2851008,2850650,2850285,2851498,2849604,2851128]
pivot_ls_scores = [2788342,2788017,2787970,2788157,2787573,2787966,2788259,2788284,2788371,2788317]
vote_scores = [2814513,2814405,2815117,2814394,2814586,2814351,2814646,2815162,2814518,2814251]
vote_ls_scores = [2787680,2787531,2788010,2787616,2787700,2787373,2787670,2787925,2787476,2787638]
order_vote_scores = [2787333,2787343,2787374,2787465,2787436,2787377,2787566,2787620,2787270,2787614]
order_vote_ls_scores = [2779316,2779487,2779519,2779593,2779623,2779432,2779587,2779876,2779579,2779556]

scores_list = [pivot_scores, pivot_ls_scores, vote_scores, vote_ls_scores, order_vote_scores, order_vote_ls_scores]

mean_scores = [np.mean(x) for x in scores_list]
print(mean_scores)
std_scores = [np.std(x) for x in scores_list]

plot_names = ["Pivot", "PLS", "Vote", "VLS", "Order", "OLS"]
x_pos = np.arange(len(plot_names))

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_scores, yerr=std_scores, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Objective Value')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Youtube Objective Values')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
plt.ylim(2760000, 2860000)
plt.show()

## PERCENT IMPROVEMENTS ##

baseline = np.mean(pivot_scores)
improvement = [100.0 * (baseline - np.mean(i)) / baseline for i in scores_list]
print(improvement)

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, improvement, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Percent Improvement')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Youtube Objective Values')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
plt.show()

## RUNNING TIMES ##

# New methods
pivot_times = [972.0,885.0,797.0,704.0,676.0,806.0,711.0,707.0,718.0,699.0]
vote_times = [3614.0,2215.0,2162.0,2033.0,2254.0,2256.0,2162.0,2162.0,2151.0,2225.0]
order_times = [3822.0,3409.0,2179.0,2254.0,1818.0,2228.0,2308.0,2027.0,2111.0,2298.0]

times_list = [pivot_times, vote_times, order_times]
times_list = [[i / 1000 for i in x] for x in times_list]

mean_times = [np.mean(x) for x in times_list]
print(mean_times)

std_times = [np.std(x) for x in times_list]

plot_names = ["Pivot", "Vote", "Order"]
x_pos = np.arange(len(plot_names))


# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_times, yerr=std_times, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Time (s)')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Youtube Times')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
plt.show()

"""

### --- ###

# New methods
pivot_scores = [2851325,2850551,2850190,2851009,2850127,2851160,2850805,2850843,2850529,2851255]
pivot_ls_scores = [2787987,2788433,2788308,2788256,2788563,2788524,2788185,2788009,2788287,2788107]
vote_scores = [2814762,2814228,2814668,2814918,2814660,2814634,2814754,2814551,2814438,2814434]
vote_ls_scores = [2787862,2787721,2788050,2788086,2787730,2787751,2787779,2787779,2787963,2787609]
order_vote_scores = [2787742,2787741,2787708,2787751,2787707,2787697,2787744,2787663,2787590,2787757]
order_vote_ls_scores = [2779765,2779837,2779838,2779895,2779511,2779736,2780013,2779691,2779736,2779796]

scores_list = [pivot_scores, pivot_ls_scores, vote_scores, vote_ls_scores, order_vote_scores, order_vote_ls_scores]

mean_scores = [np.mean(x) for x in scores_list]
print(mean_scores)
std_scores = [np.std(x) for x in scores_list]

plot_names = ["Pivot", "PLS", "Vote", "VLS", "Order", "OLS"]
x_pos = np.arange(len(plot_names))

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_scores, yerr=std_scores, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Objective Value')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Youtube 2 Objective Values')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
plt.ylim(2760000, 2860000)
plt.show()


### --- ###

# New methods
pivot_scores = [2851628,2850809,2851212,2850376,2850683,2850365,2850917,2850715,2851178,2851387]
pivot_ls_scores = [2788293,2788737,2788485,2788316,2788035,2788414,2788320,2788477,2788189,2788340]
vote_scores = [2814617,2815181,2814900,2814886,2815137,2814640,2814407,2814734,2814500,2815042]
vote_ls_scores = [2787900,2788085,2788070,2787942,2788103,2787868,2787704,2787916,2787599,2788130]
order_vote_scores = [2788273,2788136,2788225,2788361,2788071,2788183,2788234,2788104,2788169,2788096]
order_vote_ls_scores = [2780230,2780015,2780153,2780117,2780064,2780311,2780184,2780289,2779980,2779908]

scores_list = [pivot_scores, pivot_ls_scores, vote_scores, vote_ls_scores, order_vote_scores, order_vote_ls_scores]

mean_scores = [np.mean(x) for x in scores_list]
print(mean_scores)
std_scores = [np.std(x) for x in scores_list]

plot_names = ["Pivot", "PLS", "Vote", "VLS", "Order", "OLS"]
x_pos = np.arange(len(plot_names))

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_scores, yerr=std_scores, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Objective Value')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Youtube 3 Objective Values')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
plt.ylim(2760000, 2860000)
plt.show()
"""
# Out:
# [2850692.2, 2788125.6, 2814594.3, 2787661.9, 2787439.8, 2779556.8]
# [0.0, 2.1947862347257305, 1.2662854306052533, 2.2110524594693275, 2.2188435496473584, 2.49537287820833]
# [0.7675, 2.3234000000000004, 2.4454000000000002]
# ...

# %% [markdown]
# ### Livejournal

# %%
# New methods
pivot_scores = [33896257,33899653,33896594,33887696,33894527,33895367,33895476,33902180,33896541,33895732]
pivot_ls_scores = [31875565,31877836,31880173,31870058,31873905,31875872,31878257,31876777,31880360,31880366]
vote_scores = [31898161,31916169,31904757,31923299,31897887,31910570,31907474,31902248,31900868,31912449]
vote_ls_scores = [31313415,31333284,31321088,31338139,31313578,31326457,31322854,31319801,31315482,31328066]
order_vote_scores = [30869863,30923598,30916677,30911514,30892580,30914544,30922711,30887137,30911225,30914982]
order_vote_ls_scores = [30547168,30602052,30594532,30589456,30570039,30593158,30600583,30563626,30590196,30591956]

scores_list = [pivot_scores, pivot_ls_scores, vote_scores, vote_ls_scores, order_vote_scores, order_vote_ls_scores]

mean_scores = [np.mean(x) for x in scores_list]
print(mean_scores)
std_scores = [np.std(x) for x in scores_list]

plot_names = ["Pivot", "PLS", "Vote", "VLS", "Order", "OLS"]
x_pos = np.arange(len(plot_names))

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_scores, yerr=std_scores, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Objective Value')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Livejournal Objective Values')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
plt.ylim(30000000, 34000000)
plt.show()

## PERCENT IMPROVEMENTS ##

baseline = np.mean(pivot_scores)
improvement = [100.0 * (baseline - np.mean(i)) / baseline for i in scores_list]
print(improvement)

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, improvement, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Percent Improvement')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Livejournal Objective Values')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
plt.show()

## RUNNING TIMES ##

# New methods
pivot_times = [4223.0,4571.0,4380.0,3781.0,4293.0,3257.0,3526.0,4283.0,3415.0,3851.0]
vote_times = [61234.0,26243.0,25902.0,25953.0,24902.0,23322.0,25127.0,30659.0,29870.0,23318.0]
order_times = [26361.0,18856.0,19961.0,20359.0,20890.0,21073.0,20559.0,20504.0,24025.0,23463.0]

times_list = [pivot_times, vote_times, order_times]
times_list = [[i / 1000 for i in x] for x in times_list]

mean_times = [np.mean(x) for x in times_list]
print(mean_times)

std_times = [np.std(x) for x in times_list]

plot_names = ["Pivot", "Vote", "Order"]
x_pos = np.arange(len(plot_names))


# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_times, yerr=std_times, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Time (s)')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Livejournal Times')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
plt.show()


"""
### --- ###

# New methods
pivot_scores = [33895634,33894673,33897439,33899215,33898329,33898576,33899209,33894247,33893215,33892785]
pivot_ls_scores = [31886886,31872601,31873900,31876068,31875653,31871203,31870600,31874985,31869066,31876568]
vote_scores = [31918027,31886885,31891644,31917562,31906669,31901037,31885900,31898740,31885411,31903569]
vote_ls_scores = [31335260,31301754,31305539,31335547,31321298,31315491,31303391,31315379,31299878,31320377]
order_vote_scores = [30908087,30894183,30867203,30868429,30871326,30907181,30865689,30896843,30909595,30928886]
order_vote_ls_scores = [30584587,30570551,30543330,30545032,30549422,30583368,30542704,30572767,30585701,30605729]

scores_list = [pivot_scores, pivot_ls_scores, vote_scores, vote_ls_scores, order_vote_scores, order_vote_ls_scores]

mean_scores = [np.mean(x) for x in scores_list]
print(mean_scores)
std_scores = [np.std(x) for x in scores_list]

plot_names = ["Pivot", "PLS", "Vote", "VLS", "Order", "OLS"]
x_pos = np.arange(len(plot_names))

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_scores, yerr=std_scores, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Objective Value')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Livejournal 2 Objective Values')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
plt.ylim(30000000, 34000000)
plt.show()


### --- ###

# New methods
pivot_scores = [33896625,33894980,33902331,33896112,33896710,33899535,33895447,33894065,33897617,33902964]
pivot_ls_scores = [31871467,31879117,31875008,31876250,31872014,31870663,31875611,31878740,31874055,31876438]
vote_scores = [31915202,31888486,31889121,31897512,31906866,31893479,31915965,31884380,31906498,31884790]
vote_ls_scores = [31332361,31304004,31307025,31314945,31320576,31310368,31334133,31302940,31325121,31303026]
order_vote_scores = [30894432,30886174,30863557,30913918,30876650,30922630,30887044,30891098,30912688,30889273]
order_vote_ls_scores = [30574964,30562860,30540659,30593325,30554501,30600514,30563589,30568951,30590471,30568032]

scores_list = [pivot_scores, pivot_ls_scores, vote_scores, vote_ls_scores, order_vote_scores, order_vote_ls_scores]

mean_scores = [np.mean(x) for x in scores_list]
print(mean_scores)
std_scores = [np.std(x) for x in scores_list]

plot_names = ["Pivot", "PLS", "Vote", "VLS", "Order", "OLS"]
x_pos = np.arange(len(plot_names))

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_scores, yerr=std_scores, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Objective Value')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Livejournal 3 Objective Values')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
plt.ylim(30000000, 34000000)
plt.show()
"""
# Out:
# [33896002.3, 31876916.9, 31907388.2, 31323216.4, 30906483.1, 30584276.6]
# [0.0, 5.9567065818850224, 5.866810140026447, 7.59023402591638, 8.819680779877677, 9.770254529396215]
# [3.9579999999999997, 29.653, 21.6051]
# ...

# %% [markdown]
# ### Orkut

# %%
# New methods
pivot_scores = [120077478,120073047,120061995,120077070,120074075,120063477,120073917,120056153,120079164,120067983]
pivot_ls_scores = [112865420,112777911,112681642,112718768,112640561,112588645,112560335,112568408,112572320,112663777]
vote_scores = [112694039,112706639,112692210,112694853,112707728,112692249,112700013,112694735,112695974,112704131]
vote_ls_scores = [111237659,111232113,111235000,111172087,111176345,111158466,111158324,111159067,111162477,111168358]
order_vote_scores = [111549187,111549499,111554829,111544762,111550183,111547307,111547704,111542458,111541663,111556733]
order_vote_ls_scores = [110227536,110235582,110207059,110221448,110193691,110217197,110200368,110204745,110219830,110216121]

scores_list = [pivot_scores, pivot_ls_scores, vote_scores, vote_ls_scores, order_vote_scores, order_vote_ls_scores]

mean_scores = [np.mean(x) for x in scores_list]
print(mean_scores)
std_scores = [np.std(x) for x in scores_list]

plot_names = ["Pivot", "PLS", "Vote", "VLS", "Order", "OLS"]
x_pos = np.arange(len(plot_names))

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_scores, yerr=std_scores, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Objective Value')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Orkut Objective Values')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
plt.ylim(109000000, 121000000)
plt.show()

## PERCENT IMPROVEMENTS ##

baseline = np.mean(pivot_scores)
improvement = [100.0 * (baseline - np.mean(i)) / baseline for i in scores_list]
print(improvement)

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, improvement, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Percent Improvement')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Orkut Objective Values')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
plt.show()

## RUNNING TIMES ##

# New methods
pivot_times = [5230.0,4648.0,4131.0,4410.0,4068.0,3678.0,3678.0,3696.0,3657.0,3680.0]
vote_times = [96968.0,71435.0,67926.0,73122.0,70629.0,69225.0,68024.0,73457.0,68313.0,67746.0]
order_times = [84136.0,59413.0,62234.0,60651.0,62691.0,62133.0,63049.0,61359.0,59900.0,60883.0]

times_list = [pivot_times, vote_times, order_times]
times_list = [[i / 1000 for i in x] for x in times_list]

mean_times = [np.mean(x) for x in times_list]
print(mean_times)

std_times = [np.std(x) for x in times_list]

plot_names = ["Pivot", "Vote", "Order"]
x_pos = np.arange(len(plot_names))


# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_times, yerr=std_times, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Time (s)')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Orkut Times')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
plt.show()


"""
### --- ###

# New methods
pivot_scores = [120076608,120074057,120071311,120078980,120092460,120081339,120080432,120071989,120076205,120068267]
pivot_ls_scores = [112580054,112588786,112579492,112733166,112746735,112710226,112744303,112769317,112690870,112685504]
vote_scores = [112697652,112712382,112701354,112700429,112708995,112709208,112705170,112709939,112697924,112693436]
vote_ls_scores = [111173532,111179329,111172472,111175018,111198594,111184215,111183591,111198998,111196882,111188497]
order_vote_scores = [111560755,111565602,111544303,111559929,111554326,111559926,111557231,111558191,111569519,111558169]
order_vote_ls_scores = [110199440,110219637,110193596,110220637,110205671,110227135,110213148,110236669,110234963,110216829]

scores_list = [pivot_scores, pivot_ls_scores, vote_scores, vote_ls_scores, order_vote_scores, order_vote_ls_scores]

mean_scores = [np.mean(x) for x in scores_list]
print(mean_scores)
std_scores = [np.std(x) for x in scores_list]

plot_names = ["Pivot", "PLS", "Vote", "VLS", "Order", "OLS"]
x_pos = np.arange(len(plot_names))

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_scores, yerr=std_scores, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Objective Value')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Orkut 2 Objective Values')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
plt.ylim(109000000, 121000000)
plt.show()


### --- ###

# New methods
pivot_scores = [120068160,120070494,120063380,120075711,120056893,120072248,120070477,120067185,120075865,120074694]
pivot_ls_scores = [112665138,112723870,112838115,112746879,112725547,112740649,112729747,112823636,112709688,112674773]
vote_scores = [112707038,112699034,112695335,112700699,112697683,112696087,112695770,112718978,112690969,112695251]
vote_ls_scores = [111193379,111194287,111197805,111187823,111188464,111202242,111195993,111208706,111167711,111180942]
order_vote_scores = [111577702,111564000,111582372,111558479,111573707,111564119,111560962,111571855,111583325,111562828]
order_vote_ls_scores = [110239381,110222389,110253854,110227301,110217473,110217791,110220675,110220366,110242193,110225204]

scores_list = [pivot_scores, pivot_ls_scores, vote_scores, vote_ls_scores, order_vote_scores, order_vote_ls_scores]

mean_scores = [np.mean(x) for x in scores_list]
print(mean_scores)
std_scores = [np.std(x) for x in scores_list]

plot_names = ["Pivot", "PLS", "Vote", "VLS", "Order", "OLS"]
x_pos = np.arange(len(plot_names))

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_scores, yerr=std_scores, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Objective Value')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Orkut 3 Objective Values')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
plt.ylim(109000000, 121000000)
plt.show()
"""
# Out:
# [120070435.9, 112663778.7, 112698257.1, 111185989.6, 111548432.5, 110214357.7]
# [0.0, 6.168593579662354, 6.139878434471488, 7.399362077272189, 7.097503507938881, 8.20858034379802]
# [4.0876, 72.6845, 63.64489999999999]
# ...

# %% [markdown]
# ### TEMPLATE

# %%
# New methods
pivot_scores = 
pivot_ls_scores = 
vote_scores = 
vote_ls_scores = 
order_vote_scores = 
order_vote_ls_scores = 

scores_list = [pivot_scores, pivot_ls_scores, vote_scores, vote_ls_scores, order_vote_scores, order_vote_ls_scores]

mean_scores = [np.mean(x) for x in scores_list]
print(mean_scores)
std_scores = [np.std(x) for x in scores_list]

plot_names = ["Pivot", "PLS", "Vote", "VLS", "Order", "OLS"]
x_pos = np.arange(len(plot_names))

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_scores, yerr=std_scores, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Objective Value')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Amazon 1 Objective Values')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
# plt.ylim(30)
plt.show()

### --- ###

# New methods
pivot_scores = 
pivot_ls_scores = 
vote_scores = 
vote_ls_scores = 
order_vote_scores = 
order_vote_ls_scores = 

scores_list = [pivot_scores, pivot_ls_scores, vote_scores, vote_ls_scores, order_vote_scores, order_vote_ls_scores]

mean_scores = [np.mean(x) for x in scores_list]
print(mean_scores)
std_scores = [np.std(x) for x in scores_list]

plot_names = ["Pivot", "PLS", "Vote", "VLS", "Order", "OLS"]
x_pos = np.arange(len(plot_names))

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_scores, yerr=std_scores, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Objective Value')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Amazon 2 Objective Values')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
# plt.ylim(30)
plt.show()


### --- ###

# New methods
pivot_scores = 
pivot_ls_scores = 
vote_scores = 
vote_ls_scores = 
order_vote_scores = 
order_vote_ls_scores = 

scores_list = [pivot_scores, pivot_ls_scores, vote_scores, vote_ls_scores, order_vote_scores, order_vote_ls_scores]

mean_scores = [np.mean(x) for x in scores_list]
print(mean_scores)
std_scores = [np.std(x) for x in scores_list]

plot_names = ["Pivot", "PLS", "Vote", "VLS", "Order", "OLS"]
x_pos = np.arange(len(plot_names))

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_scores, yerr=std_scores, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Objective Value')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Amazon 3 Objective Values')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
# plt.ylim(30)
plt.show()

# %%
## PERCENT IMPROVEMENTS ##

baseline = np.mean(pivot_scores)
improvement = [100.0 * (baseline - np.mean(i)) / baseline for i in scores_list]
print(improvement)

# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, improvement, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Percent Improvement')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Amazon Objective Values')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
plt.show()

## RUNNING TIMES ##

# New methods
pivot_times = 
vote_times = 
order_times = 

times_list = [pivot_times, vote_times, order_times]
times_list = [[i / 1000 for i in x] for x in times_list]

mean_times = [np.mean(x) for x in times_list]
print(mean_times)

std_times = [np.std(x) for x in times_list]

plot_names = ["Pivot", "Vote", "Order"]
x_pos = np.arange(len(plot_names))


# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, mean_times, yerr=std_times, align='center', alpha=0.9, ecolor='black', capsize=10)
ax.set_ylabel('Time (s)')
ax.set_xticks(x_pos)
ax.set_xticklabels(plot_names)
ax.set_title('Amazon Times')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
plt.show()
